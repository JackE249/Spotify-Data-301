# %%
import json
import pandas as pd
import numpy as np
import spotipy
import requests
import spotipy.util as util
from spotipy.oauth2 import SpotifyOAuth
import os
from collections import defaultdict

# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
username = os.environ.get("USERNAME")
client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-read-recently-played'
data_path = f"./{username}_data"
prefix = f"{username}_"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id,
                                                client_secret,     
                                                scope=scope, 
                                                redirect_uri=redirect_uri,
                                                username=username))

# %%
identifiers_string = open(f"{data_path}/{prefix}Identifiers.json", "r").read()
identifiers_json = json.loads(identifiers_string)

inferences_string = open(f"{data_path}/{prefix}Inferences.json", "r").read()
inferences_json = json.loads(inferences_string)

marquee_string = open(f"{data_path}/{prefix}Marquee.json", "r").read()
marquee_json = json.loads(marquee_string)

playlist_string = open(f"{data_path}/{prefix}Playlist1.json", "r").read()
playlist_json = json.loads(playlist_string)

search_string = open(f"{data_path}/{prefix}SearchQueries.json", "r").read()
search_json = json.loads(search_string)

library_string = open(f"{data_path}/{prefix}YourLibrary.json", "r").read()
library_json = json.loads(library_string)

# %%
import ast
from typing import List
from os import listdir
def get_streamings(path: str) -> List[dict]:
    
    files = [f"{data_path}/{x}" for x in listdir(path)
             if x.split('.')[0][:-1] == prefix+'StreamingHistory']
    
    all_streamings = []
    
    for file in files: 
        with open(file, 'r', encoding='UTF-8') as f:
            new_streamings = ast.literal_eval(f.read())
            all_streamings += [streaming for streaming 
                               in new_streamings]
    return all_streamings

# %%
# from collections import defaultdict

# streamings = get_streamings(data_path)

# exceptions = 0
# tracks_to_ids = defaultdict()
# for i in range(len(streamings)):
#    track_name = streamings[i]['trackName']
#    if track_name in tracks_to_ids:
#       streamings[i]['id'] = tracks_to_ids[track_name]
#    else:
#       search = sp.search(q=f"track:{track_name}",type="track")
#       try:
#          id = search['tracks']['items'][0]['id']
#          streamings[i]['id'] = id
#       except: #          tracks_to_ids[track_name] = None

# with open(f'{data_path}/{prefix}history_with_ids', 'w') as f:
#    f.write(json.dumps(streamings, indent=2))
#
# nones = 0
# for x, y in tracks_to_ids.items():
#      if y == None:
#         nones+=1

# print(nones)

# %%
tracks_file = open(f'{data_path}/{prefix}history_with_ids', 'r')
tracks = json.load(tracks_file)
# drop any rows without an id
indices_to_remove = []
for i in range(len(tracks)):
   try:
      tracks[i]['id']
   except KeyError:
      indices_to_remove.append(i)
      print(tracks[i])

tracks_result = []
prev = 0
for x in indices_to_remove:
   tracks_result += tracks[prev + 1: x]
   prev = x
tracks_clean = tracks_result
# Out:
# {'endTime': '2021-08-17 22:55', 'artistName': 'LILHUDDY', 'trackName': "Don't Freak Out (feat. iann dior, Tyson Ritter & Travis Barker)", 'msPlayed': 156000}
# {'endTime': '2021-08-27 02:13', 'artistName': 'Derek Pope', 'trackName': "Don't Make Me Feel Alone", 'msPlayed': 211099}
# {'endTime': '2021-08-30 07:19', 'artistName': 'Foals', 'trackName': "I'm Done With The World (& It's Done With Me)", 'msPlayed': 182030}
# {'endTime': '2021-09-02 16:36', 'artistName': 'Murge', 'trackName': "Can't Hurt Me Now", 'msPlayed': 359572}
# {'endTime': '2021-09-03 01:27', 'artistName': 'James Blake', 'trackName': "Can't Believe The Way We Flow", 'msPlayed': 267200}
# {'endTime': '2021-09-03 02:19', 'artistName': 'John Rzeznik', 'trackName': 'I\'m Still Here (Jim\'s Theme) - From "Treasure Planet"/Soundtrack Version', 'msPlayed': 251466}
# {'endTime': '2021-09-10 01:04', 'artistName': 'The Tiny Meat Gang Podcast', 'trackName': 'Ep 202 - Cody got a haircut ft. Ben Cahn and Emil DeRosa', 'msPlayed': 847760}
# {'endTime': '2021-09-10 01:46', 'artistName': 'The Tiny Meat Gang Podcast', 'trackName': 'Ep 201 - Yik Yak is Controversial', 'msPlayed': 2471810}
# {'endTime': '2021-09-27 01:48', 'artistName': 'Mt. Joy', 'trackName': "Don't Let It Bring You Down - Recorded at Spotify Studios NYC", 'msPlayed': 170677}
# {'endTime': '2021-10-13 18:07', 'artistName': 'Terrell Hines', 'trackName': "We're All Gonna Be Killed", 'msPlayed': 195263}
# {'endTime': '2021-10-18 18:05', 'artistName': 'The Investing for Beginners Podcast - Your Path to Financial Freedom', 'trackName': 'IFB01: Optimal Portfolio Diversification for Sectors and Individual Stocks', 'msPlayed': 24807}
# {'endTime': '2021-10-18 19:04', 'artistName': 'The Investing for Beginners Podcast - Your Path to Financial Freedom', 'trackName': "IFB02: Why Timing the Market Wrong Doesn't Matter that Much", 'msPlayed': 0}
# {'endTime': '2021-10-28 03:05', 'artistName': 'Hans Zimmer', 'trackName': "Shouldn't We Get To Know Each Other First - From ''No Time To Die'' Soundtrack", 'msPlayed': 81666}
# {'endTime': '2021-10-28 06:18', 'artistName': 'Hans Zimmer', 'trackName': "Shouldn't We Get To Know Each Other First", 'msPlayed': 81666}
# {'endTime': '2020-11-06 00:17', 'artistName': 'David Bowie', 'trackName': 'Modern Love - Single Version; 1990 Remaster', 'msPlayed': 237666}
# {'endTime': '2020-11-18 23:15', 'artistName': 'Kevin Morby', 'trackName': "Don't Underestimate Midwest American Sun", 'msPlayed': 321586}
# {'endTime': '2020-11-25 20:23', 'artistName': 'Interpol', 'trackName': 'C’mere', 'msPlayed': 1216}
# {'endTime': '2020-12-02 18:03', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'All About Aerobic Base', 'msPlayed': 1854583}
# {'endTime': '2020-12-02 20:38', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Talking Injury with Staff Physical Therapist Pete Dickinson', 'msPlayed': 1303654}
# {'endTime': '2020-12-03 23:30', 'artistName': 'DROPPING IN with Mercedes Nicoll', 'trackName': "What's in your pack professional skier Chris Benchetler", 'msPlayed': 513416}
# {'endTime': '2020-12-05 18:43', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Talking High Altitude Training with David Goettler', 'msPlayed': 373120}
# {'endTime': '2020-12-05 19:56', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Scott Johnston Talks with Luke Nelson on training for ultra running.', 'msPlayed': 4272889}
# {'endTime': '2020-12-05 21:08', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Cody, Wyoming Ice Climbing', 'msPlayed': 3561}
# {'endTime': '2020-12-05 22:58', 'artistName': 'Duskus', 'trackName': "Can't stand the feeling", 'msPlayed': 207810}
# {'endTime': '2020-12-08 00:00', 'artistName': 'Interpol', 'trackName': "C'mere", 'msPlayed': 73571}
# {'endTime': '2020-12-09 22:53', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Talking Ultra Running and Ski-Mo with Mike Foote', 'msPlayed': 2777117}
# {'endTime': '2020-12-10 01:04', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Getting into SkiMo with Sam Naney, Scott Semple, and Luke Nelson', 'msPlayed': 2905675}
# {'endTime': '2020-12-10 01:05', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Talking Tactical Training with Drew Hammond', 'msPlayed': 3690}
# {'endTime': '2020-12-10 23:39', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'How a 74-y.o Athlete-In-Training Approaches Training and Mountain Goals', 'msPlayed': 4215320}
# {'endTime': '2020-12-11 06:12', 'artistName': 'Breaking Trail', 'trackName': '1: Backcountry Ski Series Part 1: How to Buy Alpine Ski Touring Boots', 'msPlayed': 1714602}
# {'endTime': '2020-12-16 21:44', 'artistName': 'Big Wild', 'trackName': "6's to 9's (feat. Rationale)", 'msPlayed': 206073}
# {'endTime': '2020-12-18 00:58', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Talking Ski Mountaineering with Nikki Larochelle and Mike Foote', 'msPlayed': 1433971}
# {'endTime': '2020-12-19 16:22', 'artistName': 'SG Lewis', 'trackName': 'Time (feat. Rhye)', 'msPlayed': 259173}
# {'endTime': '2020-12-21 13:54', 'artistName': 'Car Seat Headrest', 'trackName': "Can't Cool Me Down", 'msPlayed': 309333}
# {'endTime': '2020-12-26 14:55', 'artistName': 'Mt. Joy', 'trackName': "I'm Your Wreck", 'msPlayed': 233600}
# {'endTime': '2020-12-27 23:55', 'artistName': 'Alan Fitzpatrick', 'trackName': "Haven't You Heard - Fitzy's Fully Charged Mix", 'msPlayed': 431076}
# {'endTime': '2020-12-28 00:11', 'artistName': 'San Holo', 'trackName': "don't forget to breathe today", 'msPlayed': 247000}
# {'endTime': '2020-12-31 17:31', 'artistName': 'The Rolling Stones', 'trackName': "Can't You Hear Me Knocking - 2009 Mix", 'msPlayed': 436000}
# {'endTime': '2021-01-01 18:07', 'artistName': 'Fleetwood Mac', 'trackName': "Don't Stop - 2004 Remaster", 'msPlayed': 193346}
# {'endTime': '2021-01-03 16:08', 'artistName': 'GEAR:30', 'trackName': 'Cody Townsend on Coffee Makers, Bindings, & Beacons', 'msPlayed': 5124992}
# {'endTime': '2021-01-03 16:10', 'artistName': 'GEAR:30', 'trackName': 'Shop Talk: Backcountry Essentials, Bellingham WA', 'msPlayed': 99497}
# {'endTime': '2021-01-03 16:20', 'artistName': 'GEAR:30', 'trackName': '2020: Gear in Review', 'msPlayed': 603834}
# {'endTime': '2021-01-03 16:55', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Navigating Training Plans Through Time', 'msPlayed': 1631278}
# {'endTime': '2021-01-03 21:20', 'artistName': 'Off The Couch', 'trackName': 'Big Mtn Skier (& Trail Runner), Cody Townsend', 'msPlayed': 45952}
# {'endTime': '2021-01-03 22:05', 'artistName': 'Trail Runner Nation', 'trackName': 'Inside the head of an ultrarunner', 'msPlayed': 1836698}
# {'endTime': '2021-01-03 22:25', 'artistName': 'Trail Runner Nation', 'trackName': 'Is running that far good for me?', 'msPlayed': 902304}
# {'endTime': '2021-01-06 15:33', 'artistName': 'Backcountry Magazine Podcast', 'trackName': 'Bjarne Salén: Lensman of Legends', 'msPlayed': 2682397}
# {'endTime': '2021-01-06 15:35', 'artistName': 'Backcountry Magazine Podcast', 'trackName': 'Uphill and Beyond', 'msPlayed': 140079}
# {'endTime': '2021-01-07 17:15', 'artistName': 'Access Reality', 'trackName': 'Role of Sports in Society', 'msPlayed': 4631840}
# {'endTime': '2021-01-07 17:24', 'artistName': 'Access Reality', 'trackName': 'What is Leadership? How to Hire and manage people', 'msPlayed': 373348}
# {'endTime': '2021-01-07 21:21', 'artistName': 'Hans Zimmer', 'trackName': 'Time (From "Inception")', 'msPlayed': 280479}
# {'endTime': '2021-01-16 19:22', 'artistName': 'Sam i', 'trackName': "Don't Give Up (Heaven Edit)", 'msPlayed': 7424}
# {'endTime': '2021-01-17 19:02', 'artistName': 'Enjoy', 'trackName': "I've Wasted So Much Time", 'msPlayed': 164597}
# {'endTime': '2021-01-21 00:37', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Dr. Olga Dobranowski on balancing training, career, family life...and big mountains.', 'msPlayed': 44419}
# {'endTime': '2021-01-31 23:18', 'artistName': 'Kumarion', 'trackName': '(Give It To Me Like I) Want It', 'msPlayed': 6157}
# {'endTime': '2021-02-09 22:33', 'artistName': 'YNM Lul P-Nut', 'trackName': 'Have Mercy Many Men Remix', 'msPlayed': 2634}
# {'endTime': '2021-02-17 17:11', 'artistName': 'The SnowBrains Podcast', 'trackName': "Why Is Colorado's Backcountry the Deadliest in the USA?", 'msPlayed': 1498383}
# {'endTime': '2021-02-18 17:55', 'artistName': '', 'trackName': 'Welcome Episode - The College Investors', 'msPlayed': 56587}
# {'endTime': '2021-02-18 18:13', 'artistName': '', 'trackName': 'WTF is the Stock Market?', 'msPlayed': 1127993}
# {'endTime': '2021-02-18 18:21', 'artistName': '', 'trackName': 'The FV Equation', 'msPlayed': 460564}
# {'endTime': '2021-03-03 18:01', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Talking Strength Training for Bipedal Mountain Sports', 'msPlayed': 190891}
# {'endTime': '2021-03-12 15:51', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Talking Safety and Preparedness for Backcountry Skiing with Larry Goldie.', 'msPlayed': 2941845}
# {'endTime': '2021-03-12 17:15', 'artistName': 'Dr. Dog', 'trackName': "Where'd All the Time Go?", 'msPlayed': 234800}
# {'endTime': '2021-03-12 18:56', 'artistName': 'Host Family', 'trackName': 'Frostwire - City Girl Remix', 'msPlayed': 215248}
# {'endTime': '2021-03-20 01:10', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'Cody Townsend, Professional Free Skier and Ski Mountaineer', 'msPlayed': 3693780}
# {'endTime': '2021-03-25 23:58', 'artistName': 'LPN Deep Dives: Dune', 'trackName': 'Episode 1: Welcome to Arrakis', 'msPlayed': 59605}
# {'endTime': '2021-03-27 01:04', 'artistName': 'Uphill Athlete Podcast', 'trackName': 'High Altitude Expedition Doctor, Monica Piris M.D.', 'msPlayed': 1016493}
# {'endTime': '2021-04-05 16:48', 'artistName': 'Hallucinogenius', 'trackName': "Don't Assume My Genre", 'msPlayed': 310000}
# {'endTime': '2021-05-04 19:03', 'artistName': 'Flying Lotus', 'trackName': 'Your Lord', 'msPlayed': 126533}
# {'endTime': '2021-05-07 22:15', 'artistName': 'The Beach Boys', 'trackName': "Wouldn't It Be Nice - Stereo / Remastered", 'msPlayed': 153205}
# {'endTime': '2021-05-09 20:15', 'artistName': 'The Kid LAROI', 'trackName': 'NOT FAIR (feat. Corbin)', 'msPlayed': 166688}
# {'endTime': '2021-05-10 18:39', 'artistName': 'On Planets', 'trackName': "Don't Think So Hard", 'msPlayed': 63360}
# {'endTime': '2021-05-29 18:45', 'artistName': 'IHF', 'trackName': "Don't Forget My Love", 'msPlayed': 154434}
# {'endTime': '2021-06-03 02:29', 'artistName': 'Cole Jackson', 'trackName': 'See You On The Other Side', 'msPlayed': 5875}
# {'endTime': '2021-06-14 22:14', 'artistName': 'Apashe', 'trackName': "I'm Fine - IMANU Remix", 'msPlayed': 243977}
# {'endTime': '2021-06-18 21:50', 'artistName': 'Dreamville', 'trackName': "Don't Hit Me Right Now (with Bas & Cozz feat. Yung Baby Tate, Guapdad 4000 & Buddy)", 'msPlayed': 174360}
# {'endTime': '2021-07-02 17:13', 'artistName': 'Major Lazer', 'trackName': "C'est Cuit (feat. Aya Nakamura & Swae Lee) - Major Lazer VIP Remix", 'msPlayed': 137735}
# {'endTime': '2021-07-07 15:31', 'artistName': 'Your Own Backyard', 'trackName': 'Episode 09: The Beginning of The End Part 1', 'msPlayed': 318229}
# {'endTime': '2021-07-09 15:09', 'artistName': 'J. Cole', 'trackName': "Ain't That Some Shit - Interlude", 'msPlayed': 3413}
# {'endTime': '2021-07-19 15:31', 'artistName': 'BiggerPockets Money Podcast', 'trackName': '1: The Surprising (Scientific) Truth Behind What Makes You Successful with Mr. Money Mustache', 'msPlayed': 637312}
# {'endTime': '2021-08-06 22:36', 'artistName': 'HUGEL', 'trackName': "Can't Love Myself (feat. Mishaal & LPW)", 'msPlayed': 59721}
# {'endTime': '2021-08-14 05:12', 'artistName': 'The Kid LAROI', 'trackName': "DON'T LEAVE ME (feat. G Herbo & Lil Durk)", 'msPlayed': 167965}

# %%
tracks_df = pd.DataFrame(tracks).dropna(subset=["id"], axis=0)
unique_ids = tracks_df['id'].unique()
block = 0
features = []
while(len(unique_ids) - block > 0):
   ids = unique_ids[block:block + 100]
   block+=100
   features += sp.audio_features(ids)

# %%
features = temp = np.array(features)
features = list(temp[~pd.isna(temp)])

# %%
# AFTER RUNNING THE TWO QUERIES THIS SHOULD BE THE FINAL FILE WITH SONG IDS AND FEATURES OF EACH
pd.merge(tracks_df, pd.DataFrame(features), on='id', how='left').to_csv(f'{data_path}/{prefix}history_with_features', index=False)
dataset_df = pd.read_csv(f'{data_path}/{prefix}history_with_features')

# %%
dataset_df
# Out:
#                 endTime         artistName  \
# 0      2021-08-17 22:43       Trippie Redd
# 1      2021-08-17 22:47       Trippie Redd
# 2      2021-08-17 22:49             WILLOW
# 3      2021-08-17 22:52  Machine Gun Kelly
# 4      2021-08-17 22:58       Trippie Redd
# ...                 ...                ...
# 12658  2021-08-17 22:29       Trippie Redd
# 12659  2021-08-17 22:33       Trippie Redd
# 12660  2021-08-17 22:35       Trippie Redd
# 12661  2021-08-17 22:38       Trippie Redd
# 12662  2021-08-17 22:41       Trippie Redd
#
#                                                trackName  msPlayed  \
# 0                                                LEADERS    160993
# 1                                           FROZEN OCEAN    196169
# 2      t r a n s p a r e n t s o u l feat. Travis Barker    168398
# 3       I Think I'm OKAY (with YUNGBLUD & Travis Barker)    169397
# 4      PILL BREAKER (feat. blackbear & Machine Gun Ke...    177058
# ...                                                  ...       ...
# 12658                  RED SKY (feat. Machine Gun Kelly)    152149
# 12659                                           MEGLADON    194992
# 12660                                      SAVE YOURSELF    160729
# 12661                                            DREAMER    170000
# 12662                                        IT'S COMING    154120
#
#                            id  danceability  energy   key  loudness  mode  \
# 0      4D7NrSeqkTarBrJ80b2sBc         0.950   0.654   0.0    -5.895   0.0
# 1      5ypQ8scn8g2l0341ErES0B         0.314   0.762   2.0    -3.136   1.0
# 2      1QL7nSDZCwZMnbisV4KOXt         0.390   0.830  11.0    -5.201   0.0
# 3      2gTdDMpNxIRFSiu7HutMCg         0.628   0.744   7.0    -4.718   1.0
# 4      7jjnn6K7p5MgOFuqLypAcM         0.527   0.790   2.0    -6.268   1.0
# ...                       ...           ...     ...   ...       ...   ...
# 12658  0yFfjXtSDkr81WVAPPS1Q4         0.472   0.769   7.0    -4.198   1.0
# 12659  5Kq6LIFZsVD99rb7iT0QTG         0.453   0.739   7.0    -4.977   1.0
# 12660  6FhB5ZyT4JsIJ0ozDlXCIp         0.503   0.921   8.0    -5.907   0.0
# 12661  4yZEX3NsnXfobmZ0m8ZO4Y         0.723   0.751   9.0    -5.233   0.0
# 12662  3dhjNA0jGA8vHBQ1VdD6vV         0.773   0.819   0.0    -5.946   0.0
#
#        ...  instrumentalness  liveness  valence    tempo            type  \
# 0      ...          0.000000    0.1380    0.886  132.936  audio_features
# 1      ...          0.000022    0.1160    0.310  134.582  audio_features
# 2      ...          0.000000    0.1560    0.191   90.021  audio_features
# 3      ...          0.000000    0.3130    0.277  119.921  audio_features
# 4      ...          0.000000    0.3700    0.236  153.034  audio_features
# ...    ...               ...       ...      ...      ...             ...
# 12658  ...          0.000000    0.2390    0.587  159.999  audio_features
# 12659  ...          0.000000    0.6940    0.258  139.962  audio_features
# 12660  ...          0.000003    0.2600    0.359  121.983  audio_features
# 12661  ...          0.000000    0.0680    0.642  126.999  audio_features
# 12662  ...          0.000000    0.0679    0.585   92.987  audio_features
#
#                                         uri  \
# 0      spotify:track:4D7NrSeqkTarBrJ80b2sBc
# 1      spotify:track:5ypQ8scn8g2l0341ErES0B
# 2      spotify:track:1QL7nSDZCwZMnbisV4KOXt
# 3      spotify:track:2gTdDMpNxIRFSiu7HutMCg
# 4      spotify:track:7jjnn6K7p5MgOFuqLypAcM
# ...                                     ...
# 12658  spotify:track:0yFfjXtSDkr81WVAPPS1Q4
# 12659  spotify:track:5Kq6LIFZsVD99rb7iT0QTG
# 12660  spotify:track:6FhB5ZyT4JsIJ0ozDlXCIp
# 12661  spotify:track:4yZEX3NsnXfobmZ0m8ZO4Y
# 12662  spotify:track:3dhjNA0jGA8vHBQ1VdD6vV
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/4D7NrSeqkTar...
# 1      https://api.spotify.com/v1/tracks/5ypQ8scn8g2l...
# 2      https://api.spotify.com/v1/tracks/1QL7nSDZCwZM...
# 3      https://api.spotify.com/v1/tracks/2gTdDMpNxIRF...
# 4      https://api.spotify.com/v1/tracks/7jjnn6K7p5Mg...
# ...                                                  ...
# 12658  https://api.spotify.com/v1/tracks/0yFfjXtSDkr8...
# 12659  https://api.spotify.com/v1/tracks/5Kq6LIFZsVD9...
# 12660  https://api.spotify.com/v1/tracks/6FhB5ZyT4JsI...
# 12661  https://api.spotify.com/v1/tracks/4yZEX3NsnXfo...
# 12662  https://api.spotify.com/v1/tracks/3dhjNA0jGA8v...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/4D7N...    194844.0
# 1      https://api.spotify.com/v1/audio-analysis/5ypQ...    204233.0
# 2      https://api.spotify.com/v1/audio-analysis/1QL7...    168030.0
# 3      https://api.spotify.com/v1/audio-analysis/2gTd...    169397.0
# 4      https://api.spotify.com/v1/audio-analysis/7jjn...    177059.0
# ...                                                  ...         ...
# 12658  https://api.spotify.com/v1/audio-analysis/0yFf...    152149.0
# 12659  https://api.spotify.com/v1/audio-analysis/5Kq6...    194992.0
# 12660  https://api.spotify.com/v1/audio-analysis/6FhB...    221160.0
# 12661  https://api.spotify.com/v1/audio-analysis/4yZE...    190849.0
# 12662  https://api.spotify.com/v1/audio-analysis/3dhj...    269187.0
#
#       time_signature
# 0                4.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                3.0
# ...              ...
# 12658            4.0
# 12659            4.0
# 12660            4.0
# 12661            4.0
# 12662            4.0
#
# [12663 rows x 22 columns]
